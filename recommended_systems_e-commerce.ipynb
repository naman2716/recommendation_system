# %%
from keras.models import Sequential

# %%
import numpy as np
import pandas as pd

# %%
model = Sequential()

# %%
from keras.layers import Dense

# %%
model.add(Dense(units = 32 , activation = 'relu' , input_dim = 3))
model.add(Dense(units = 16 , activation = 'relu' ,input_dim =3))
model.add(Dense(units = 6 , activation = 'sigmoid',input_dim = 3))

# %%
#compile
# optimizer
# loss function : to calculate cost
# metrics

# %%
model.compile(optimizer = 'adam' , loss = 'mean_squared_error' , metrics = ['accuracy'])

# %%
#fitting the data 
# x
# y
# epocks = no. of iterations we need so that the forward and the backward propagation should run
# batch_size
# validation_data = x_test , y_test

# %%
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)
# Out:
# C:\Users\singh\Anaconda3\lib\site-packages\sklearn\utils\validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)

# %%
train = pd.read_csv("customer_history.csv" , delimiter = ',' , encoding = "ISO-8859-1")
train
# Out:
#     productID productTypeCode  No.of unit customerID  unit price productName  \
# 0           1            CAT1           5      CUS@$        2000      mobile
# 1           2            CAT5           8      CUS@$        2000      mobile
# 2           3            CAT8           4      CUS@$        2000     T-Shirt
# 3           4            CAT1           5      CUS@$        6000     T-Shirt
# 4           5            CAT5           8      CUS@$        1000         bat
# 5           6            CAT5           5      CUS@$        6000     T-Shirt
# 6           7            CAT3           8      CUS@$        6000      mobile
# 7           8           CAT10           4      CUS@$        5000    pendrive
# 8           9            CAT9           8      CUS@$        5000         bat
# 9          10            CAT1           3      CUS@$        3000         bat
# 10         11            CAT1           7      CUS@$        2000       Shoes
# ...

# %%
del train['productTypeCode']
del train['customerID']
del train['productName']
train
# Out:
#     productID  No.of unit  unit price  productType
# 0           1           5        2000            1
# 1           2           8        2000            1
# 2           3           4        2000            2
# 3           4           5        6000            2
# 4           5           8        1000            3
# 5           6           5        6000            2
# 6           7           8        6000            1
# 7           8           4        5000            4
# 8           9           8        5000            3
# 9          10           3        3000            3
# 10         11           7        2000            5
# 11         12           1        5000            1
# 12         13           5        6000            4
# 13         14           8        5000            6
# 14         15           5        1000            3
# 15         16           8        4000            2
# 16         17           4        2000            6
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
train_data = np.array(train.iloc[: , :3])
train_target = np.array(train.iloc[: , 3:4])
train_data
# Out:
# array([[   1,    5, 2000],
#        [   2,    8, 2000],
#        [   3,    4, 2000],
#        [   4,    5, 6000],
#        [   5,    8, 1000],
#        [   6,    5, 6000],
#        [   7,    8, 6000],
#        [   8,    4, 5000],
#        [   9,    8, 5000],
#        [  10,    3, 3000],
#        [  11,    7, 2000],
#        [  12,    1, 5000],
#        [  13,    5, 6000],
#        [  14,    8, 5000],
#        [  15,    5, 1000],
#        [  16,    8, 4000],
#        [  17,    4, 2000],
#        [  18,    4, 4000],
#        [  19,    1, 1000],
#        [  20,    3, 4000],
#        [  21,    8, 4000],
#        [  22,    8, 5000],
#        [  23,    8, 6000],
#        [  24,    4, 2000],
#        [  25,    8, 1000],
#        [  26,    7, 3000],
#        [  27,    8, 6000],
#        [  28,    5, 3000],
#        [  29,    3, 3000],
#        [  30,    7, 2000],
#        [  31,    3, 6000],
#        [  32,    7, 5000],
#        [  33,    5, 3000],
#        [  34,    8, 2000],
# ...

# %%
x_train , x_test , y_train , y_test = train_test_split(train_data , train_target)

# %%
model.fit(x = x_train , y = y_train , epochs = 100 )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-91-1f08685b2436> in <module>()
# ----> 1 model.fit(x = x_train , y = y_train , epochs = 100 )
#
# ~\Anaconda3\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#     948             sample_weight=sample_weight,
#     949             class_weight=class_weight,
# --> 950             batch_size=batch_size)
#     951         # Prepare validation data.
#     952         do_validation = False
#
# ~\Anaconda3\lib\site-packages\keras\engine\training.py in _standardize_user_data(self, x, y, sample_weight, class_weight, check_array_lengths, batch_size)
#     785                 feed_output_shapes,
# ...

# %%
predictions = model.predict(x_test)
print(predictions)
score = model.evaluate(x_test , y_test)
score
# Out:
# [[2.52605915e-19]
#  [9.57700968e-01]
#  [1.00000000e+00]
#  [9.99999285e-01]
#  [1.00000000e+00]
#  [1.00000000e+00]
#  [1.00000000e+00]
#  [1.00000000e+00]
#  [1.00000000e+00]
#  [1.00000000e+00]
#  [3.05058181e-01]
#  [9.99997973e-01]
#  [1.00000000e+00]
#  [3.49096805e-01]
#  [3.77347344e-04]
#  [6.31363879e-23]
#  [1.00000000e+00]
#  [6.82455286e-33]
#  [8.68823670e-34]
#  [0.00000000e+00]
#  [6.81821593e-22]
#  [6.14208943e-18]
#  [1.00000000e+00]
#  [1.00000000e+00]
#  [7.55728932e-26]
#  [1.00000000e+00]
#  [1.00000000e+00]
#  [1.32488204e-13]
#  [1.00000000e+00]
#  [0.00000000e+00]
#  [1.00000000e+00]
#  [4.04943503e-25]
#  [9.99994755e-01]
#  [9.30718913e-19]
#  [1.00000000e+00]
#  [3.12037673e-17]
#  [9.99999762e-01]
#  [3.90341873e-26]
#  [1.00000000e+00]
#  [6.70601219e-21]
#  [4.61075711e-09]
#  [1.00000000e+00]
#  [1.73573972e-05]
#  [1.00000000e+00]
#  [1.00000000e+00]
#  [0.00000000e+00]
#  [1.00000000e+00]
#  [9.99999285e-01]
#  [1.00000000e+00]
#  [7.75539639e-31]
# ...
